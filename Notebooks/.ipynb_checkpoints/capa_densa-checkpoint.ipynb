# %% [markdown]
# ## Capa densa
#
# Una capa densa és un conjunt de neurones que reben **totes** les entrades
# i cada una genera una sortida independent.
#
# Si tenim $n$ entrades i $m$ neurones, la capa fa:
#
# $$Z = X \cdot W + b$$
#
# On:
# - $X$ és el vector d'entrades, de forma $(1 \times n)$
# - $W$ és la matriu de pesos, de forma $(n \times m)$
# - $b$ és el vector de biaixos, de forma $(1 \times m)$
# - $Z$ és la sortida abans de l'activació, de forma $(1 \times m)$
#
# La sortida final de la capa és:
#
# $$A = \sigma(Z)$$
#
# Cada columna de $W$ representa els pesos d'una neurona concreta.

# %%
import numpy as np

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def capa_densa(X, W, b):
    Z = np.dot(X, W) + b       # combinació lineal: (1×n) · (n×m) = (1×m)
    return sigmoid(Z)          # activació de cada neurona

# Exemple: 3 entrades, 4 neurones
X = np.array([0.5, 0.3, 0.8])  # vector d'entrades: 3 entrades
W = np.random.randn(3, 4)      # matriu de pesos: 3 files | 4 columnes
b = np.random.randn(4)         # vector de biaixos: 4 biaixos per a cada neurona

A = capa_densa(X, W, b)

print(W)
print(b)
print(f"Sortida de la capa (4 neurones): {A}")
# Out:
# [[ 0.19176148 -0.68180745  0.25030295 -0.43830992]
#  [ 0.39277242 -0.92235543  0.88584642 -0.62590587]
#  [-0.6740507  -0.85086231 -0.66685189 -1.45522543]]
# [ 0.10782867 -0.19680502  0.19595589 -0.55531403]
# Sortida de la capa (4 neurones): [0.44578908 0.1831567  0.51334178 0.10655523]

# %%
# Visualització dels pesos de cada neurona
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 4, figsize=(12, 3))

for i, ax in enumerate(axes):
    ax.bar(range(3), W[:, i], color='steelblue', alpha=0.7)
    ax.axhline(0, color='gray', linewidth=0.8)
    ax.set_title(f'Neurona {i+1}')
    ax.set_xlabel('Entrada')
    ax.set_ylabel('Pes')
    ax.set_xticks(range(3))
    ax.set_xticklabels(['x₁', 'x₂', 'x₃'])

plt.suptitle('Pesos de cada neurona de la capa', fontsize=13)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Visualització dels pesos de cada neurona
# ----> 2 import matplotlib.pyplot as plt
#       3
#       4 fig, axes = plt.subplots(1, 4, figsize=(12, 3))
#       5
#
# File ~/.local/lib/python3.14/site-packages/matplotlib/__init__.py:161
#     157 from packaging.version import parse as parse_version
#     159 # cbook must import matplotlib only within function
#     160 # definitions, so it is safe to import from it here.
# --> 161 from . import _api, _version, cbook, _docstring, rcsetup
#     162 from matplotlib._api import MatplotlibDeprecationWarning
#     163 from matplotlib.rcsetup import cycler  # noqa: F401
#
# File ~/.local/lib/python3.14/site-packages/matplotlib/rcsetup.py:29
#      27 from matplotlib.cbook import ls_mapper
#      28 from matplotlib.colors import Colormap, is_color_like
# ---> 29 from matplotlib._fontconfig_pattern import parse_fontconfig_pattern
#      30 from matplotlib._enums import JoinStyle, CapStyle
#      32 # Don't let the original cycler collide with our validating cycler
#
# File ~/.local/lib/python3.14/site-packages/matplotlib/_fontconfig_pattern.py:15
#      12 from functools import lru_cache, partial
#      13 import re
# ---> 15 from pyparsing import (
#      16     Group, Optional, ParseException, Regex, StringEnd, Suppress, ZeroOrMore, one_of)
#      19 _family_punc = r'\\\-:,'
#      20 _family_unescape = partial(re.compile(r'\\(?=[%s])' % _family_punc).sub, '')
#
# ModuleNotFoundError: No module named 'pyparsing'
